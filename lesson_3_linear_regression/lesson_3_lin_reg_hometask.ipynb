# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np 
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.metrics import mean_squared_error, r2_score

# %%
diabetes=load_diabetes()
X=diabetes.data
y=diabetes.target
print(X.shape, y.shape)
# Out:
# (442, 10) (442,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2018)

# %% [markdown]
# Ridge регресія

# %%
ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)

y_pred_ridge = ridge.predict(X_test)

print("Ridge MSE:", mean_squared_error(y_test, y_pred_ridge))
print("Ridge R2:", r2_score(y_test, y_pred_ridge))
# Out:
# Ridge MSE: 3559.6703842678235
# Ridge R2: 0.36557482560223586

# %% [markdown]
# Lasso

# %%
lasso = Lasso(alpha=0.1)
lasso.fit(X_train, y_train)

y_pred_lasso = lasso.predict(X_test)

print("Lasso MSE:", mean_squared_error(y_test, y_pred_lasso))
print("Lasso R2:", r2_score(y_test, y_pred_lasso))
# Out:
# Lasso MSE: 3090.711997058206
# Lasso R2: 0.4491553188708426

# %% [markdown]
# Polynomial

# %%
poly = PolynomialFeatures(degree=2)

X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

model_poly = LinearRegression()
model_poly.fit(X_train_poly, y_train)

y_pred_poly = model_poly.predict(X_test_poly)

print("Polynomial MSE:", mean_squared_error(y_test, y_pred_poly))
print("Polynomial R2:", r2_score(y_test, y_pred_poly))
# Out:
# Polynomial MSE: 3317.559228922278
# Polynomial R2: 0.4087252848786319

# %% [markdown]
# All results

# %%
results = pd.DataFrame({
    "Model": ["Ridge", "Lasso", "Polynomial"],
    "MSE": [
        mean_squared_error(y_test, y_pred_ridge),
        mean_squared_error(y_test, y_pred_lasso),
        mean_squared_error(y_test, y_pred_poly)
    ],
    "R2": [
        r2_score(y_test, y_pred_ridge),
        r2_score(y_test, y_pred_lasso),
        r2_score(y_test, y_pred_poly)
    ]
})

print(results)
# Out:
#         Model          MSE        R2
# 0       Ridge  3559.670384  0.365575
# 1       Lasso  3090.711997  0.449155
# 2  Polynomial  3317.559229  0.408725
